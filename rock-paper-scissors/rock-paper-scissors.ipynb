# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
import random

options = ["stone", "paper", "scissors"]
max_games = 3
victory = 2

def choice():
    return random.choice(options)

def player_choice():
    player = input("Choose between paper, stone or scissors ")
    player = player.lower()
    while player not in options:
        player = input("That is not correct. Try again!")
        if player in options:
            break
    return player

def combat(machine, player):
    if machine == player:
        return 0
    elif (machine == "stone" and player =="scissors") or (machine=="paper" and player == "stone") or (machine == "scissors" and player =="paper"):
        return 1
    else:
        return 2
        
def game(machine, player, score, machine_p, player_p):
    print(f"Machine has chose: {machine}")
    print(f"Player has chose: {player}")
    if combat==0:
        print("Tie!")
        print(f"Score: Machine {machine_p} - {player_p} Player")       
    elif combat==1:
        print(f"Score: Machine {machine_p} - {player_p} Player")
    else:
        print(f"Score: Machine {machine_p} - {player_p} Player")
    return (f"Machine choice:{machine}, Player choice:{player}, Machine wins:{machine_p}, player wins:{player_p}")
    
machine_points=0
player_points=0

while machine_points < victory or player_points < victory:
    if machine_points == victory:
        break
    elif player_points == victory:
        break
    else:
        machine = choice()
        player = player_choice()
        score = combat(machine, player)
        if score == 1:
            machine_points += 1
        elif score == 2:
            player_points += 1
        else:
            pass
        game(machine, player, score, machine_points, player_points)
    
if machine_points == victory:
    print("Ooooh, you lose!")
elif player_points == victory:
    print("Congratulations! You have won!")
# Out:
# Choose between paper, stone or scissors paper
# Machine has chose: stone
# Player has chose: paper
# Score: Machine 0 - 1 Player
# Choose between paper, stone or scissors scissors
# Machine has chose: stone
# Player has chose: scissors
# Score: Machine 1 - 1 Player
# Choose between paper, stone or scissors stone
# Machine has chose: paper
# Player has chose: stone
# Score: Machine 2 - 1 Player
# Ooooh, you lose!

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
import random

def number_games():
    number = int(input("How many times do you want to play? (Must be odd number)"))
    while number % 2 != 1:
        number = int(input("Number of games must be odd number, you fool"))
        if number % 2 == 1:
            break
    return number

options = ['stone', 'paper', 'scissors', 'lizard', 'spock']

games = number_games()

victory = int(games/2 + 1)

def machine():
    return random.choice(options)

def player_choice ():
    player = input("Choose between stone, paper, scissors, lizard or spock ")
    while player not in options:
        player = input("That is not correct. Try again!")
        if player in options:
            break
    return player

def resolve_combat (machine, player):
    if machine == player:
        return 0
    elif machine == 'stone' and ((player=='scissors') or (player=='lizard')):
        return 1
    elif machine == 'paper' and ((player == 'stone') or (player=='spock')):
        return 1
    elif machine == 'scissors' and ((player == 'paper') or (player=='lizard')):
        return 1
    elif machine == 'lizard' and ((player == 'paper') or (player=='spock')):
        return 1
    elif machine == 'spock' and ((player == 'stone') or (jugador=='scissors')):
        return 1
    else:
        return 2
    
def game(machine, player, score, machine_p, player_p):
    print(f"Machine has chose: {machine}")
    print(f"Player has chose: {player}")
    if combat==0:
        print("Tie!")
        print(f"Score: Machine {machine_p} - {player_p} Player")       
    elif combat==1:
        print(f"Score: Machine {machine_p} - {player_p} Player")
    else:
        print(f"Score: Machine {machine_p} - {player_p} Player")
    return (f"Machine choice:{machine}, Player choice:{player}, Machine wins:{machine_p}, player wins:{player_p}")
    
machine_points=0
player_points=0

while machine_points < victory or player_points < victory:
    if machine_points == victory:
        break
    elif player_points == victory:
        break
    else:
        machine = choice()
        player = player_choice()
        score = combat(machine, player)
        if score == 1:
            machine_points += 1
        elif score == 2:
            player_points += 1
        else:
            pass
        game(machine, player, score, machine_points, player_points)

if machine_points == victory:
    print("Ooooh, you lose!")
elif player_points == victory:
    print("Congratulations! You have won!")
# Out:
# How many times do you want to play? (Must be odd number)3
# Choose between stone, paper, scissors, lizard or spock lizard
# Machine has chose: paper
# Player has chose: lizard
# Score: Machine 0 - 1 Player
# Choose between stone, paper, scissors, lizard or spock paper
# Machine has chose: lizard
# Player has chose: paper
# Score: Machine 1 - 1 Player
# Choose between stone, paper, scissors, lizard or spock spock
# Machine has chose: scissors
# Player has chose: spock
# Score: Machine 1 - 2 Player
# Congratulations! You have won!

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
